# %% [markdown]
# ---
#
# # 📈 Real-Time Tick-by-Tick Data from IBKR with Python - Building Dollar Bars
# Interactive Brokers (IBKR) provides some of the cheapest real-time market data available - including tick-by-tick trade data. In this tutorial, we'll walk through how to stream that data using ib_async and apply it to build dollar bars, which group trades by total dollar value exchanged rather than by time.
#
# ---
#
# # ⚙️ What is ib_async?
# ib_async is the actively maintained successor to ib_insync, following the tragic passing of its original creator, Ewald de Wit. It provides a clean, async-friendly API over the IBKR TWS and Gateway.
#
#
#
# #### IBKR API DOCS
# https://interactivebrokers.github.io/tws-api/tick_data.html
# ---
#
# # 🚀 Step 1: Connect to IBKR
# Make sure you have either TWS or IB Gateway running and listening on port 4001:

# %%
from ib_async import *
ib = IB()
util.startLoop()
ib.connect(port=4001,clientId=0)
# Out:
# <IB connected to 127.0.0.1:4001 clientId=0>

# %% [markdown]
# # 📡 Step 2: Subscribe to Tick-by-Tick Data
#
# Let's request tick-level trade data for TSLA:

# %%
stock = Stock(symbol='TSLA',exchange='SMART',currency='USD')
ticker = ib.reqTickByTickData(stock,"Last")

# %%
ticker.tickByTicks
# Out:
# [TickByTickAllLast(tickType=1, time=datetime.datetime(2025, 7, 7, 10, 47, 35, 499689, tzinfo=datetime.timezone.utc), price=294.0, size=119.0, tickAttribLast=TickAttribLast(pastLimit=False, unreported=False), exchange='ARCA', specialConditions='FT'),
#  TickByTickAllLast(tickType=1, time=datetime.datetime(2025, 7, 7, 10, 47, 35, 499689, tzinfo=datetime.timezone.utc), price=293.95, size=144.0, tickAttribLast=TickAttribLast(pastLimit=False, unreported=False), exchange='ARCA', specialConditions='FT')]

# %% [markdown]
# * 'Last': includes only officially reported trades
# * 'AllLast': includes all last trades, including unreported or dark pool prints
#
#
# ---
#
# # 🛠️ Step 3: Register Tick Handlers
# ### Option 1: Ticker-Specific Handler

# %%
ticks = []
def on_new_tick(ticker:Ticker):
    global ticks
    ticks.extend(ticker.tickByTicks)

# %%
ticker.updateEvent.clear()
#ticker.updateEvent+=on_new_tick

# %%
util.df(ticks)
# Out:
#     tickType                             time   price   size  \
# 0          1 2025-07-07 10:49:54.394788+00:00  294.00  100.0
# 1          1 2025-07-07 10:49:54.394788+00:00  293.99  125.0
# 2          1 2025-07-07 10:49:57.922455+00:00  294.05  100.0
# 3          1 2025-07-07 10:49:57.923471+00:00  294.07  100.0
# 4          1 2025-07-07 10:50:11.008502+00:00  293.98  100.0
# 5          1 2025-07-07 10:50:11.008502+00:00  293.95  103.0
# 6          1 2025-07-07 10:50:11.009516+00:00  293.95  200.0
# 7          1 2025-07-07 10:50:11.009516+00:00  293.95  200.0
# 8          1 2025-07-07 10:50:11.009516+00:00  293.95  200.0
# 9          1 2025-07-07 10:50:12.820209+00:00  293.95  200.0
# 10         1 2025-07-07 10:50:24.632733+00:00  293.98  150.0
# 11         1 2025-07-07 10:50:29.560908+00:00  293.95  100.0
# 12         1 2025-07-07 10:50:30.315006+00:00  293.90  196.0
# 13         1 2025-07-07 10:50:30.315006+00:00  293.90  200.0
# 14         1 2025-07-07 10:50:30.967569+00:00  293.91  100.0
# 15         1 2025-07-07 10:50:31.661486+00:00  293.90  100.0
# 16         1 2025-07-07 10:50:31.661486+00:00  293.90  100.0
# 17         1 2025-07-07 10:50:31.661486+00:00  293.90  142.0
# 18         1 2025-07-07 10:50:32.290402+00:00  293.90  200.0
# 19         1 2025-07-07 10:50:32.290402+00:00  293.90  240.0
# 20         1 2025-07-07 10:50:32.977224+00:00  293.93  100.0
# 21         1 2025-07-07 10:50:40.357057+00:00  293.85  200.0
# 22         1 2025-07-07 10:50:40.357057+00:00  293.85  200.0
# 23         1 2025-07-07 10:50:40.357057+00:00  293.85  200.0
# 24         1 2025-07-07 10:50:41.415542+00:00  293.85  200.0
# 25         1 2025-07-07 10:50:48.998850+00:00  293.93  100.0
# 26         1 2025-07-07 10:50:48.998850+00:00  293.93  147.0
# 27         1 2025-07-07 10:50:48.999851+00:00  293.99  100.0
# 28         1 2025-07-07 10:50:48.999851+00:00  293.99  100.0
#
#                                        tickAttribLast  exchange  \
# 0   TickAttribLast(pastLimit=False, unreported=False)    ISLAND
# 1   TickAttribLast(pastLimit=False, unreported=False)    ISLAND
# 2   TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 3   TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 4   TickAttribLast(pastLimit=False, unreported=False)    ISLAND
# 5   TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 6   TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 7   TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 8   TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 9   TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 10  TickAttribLast(pastLimit=False, unreported=False)  DRCTEDGE
# 11  TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 12  TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 13  TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 14  TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 15  TickAttribLast(pastLimit=False, unreported=False)    ISLAND
# 16  TickAttribLast(pastLimit=False, unreported=False)    ISLAND
# 17  TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 18  TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 19  TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 20  TickAttribLast(pastLimit=False, unreported=False)    ISLAND
# 21  TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 22  TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 23  TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 24  TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 25  TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 26  TickAttribLast(pastLimit=False, unreported=False)      ARCA
# 27  TickAttribLast(pastLimit=False, unreported=False)    ISLAND
# 28  TickAttribLast(pastLimit=False, unreported=False)      ARCA
#
#    specialConditions
# 0                 FT
# 1                  T
# 2                  T
# 3                  T
# 4                  T
# 5                 FT
# 6                 FT
# 7                 FT
# 8                 FT
# 9                  T
# 10                FT
# 11                FT
# 12                FT
# 13                FT
# 14                FT
# 15                 T
# 16                 T
# 17                 T
# 18                 T
# 19                 T
# 20                FT
# 21                FT
# 22                FT
# 23                FT
# 24                 T
# 25                FT
# 26                FT
# 27                FT
# 28                FT

# %% [markdown]
# ### Option 2: Global Callback for All Tickers

# %%
ticks = []
def on_new_tick(tickers:set[Ticker]):
    global ticks
    for ticker in tickers: # TODO be careful if more than 1 ticker this is a bug because you duplicate the last tickByTicks..
        ticks.extend(ticker.tickByTicks)

# %%
ib.pendingTickersEvent+=on_new_tick

# %%
ticks
# Out:
# []

# %% [markdown]
# ## You can view your collected data with:

# %%
util.df(ticks)
# Out:
#    tickType                             time   price   size  \
# 0         1 2025-07-07 10:54:00.663946+00:00  294.29  100.0
# 1         1 2025-07-07 10:54:00.663946+00:00  294.29  100.0
#
#                                       tickAttribLast  exchange  \
# 0  TickAttribLast(pastLimit=False, unreported=False)  DRCTEDGE
# 1  TickAttribLast(pastLimit=False, unreported=False)  DRCTEDGE
#
#   specialConditions
# 0                FT
# 1                FT

# %% [markdown]
# Each tick contains fields such as price, size, time, exchange, and attributes like tickAttribLast.
#
# ---
# # 🧽 Step 4: Clean Up Callbacks
# To prevent future duplication or memory issues, clear the callbacks when done:

# %%
ib.pendingTickersEvent.clear()

# %% [markdown]
# # 💰 Step 5: Real-Time Dollar Bars
#
# Dollar bars group ticks such that each bar corresponds to a fixed dollar amount traded - for example, $500,000.
#
# This creates a more consistent information flow than time bars, especially during low- or high-activity periods.
#
# Here's a simple class to build them:

# %%
util.df(ticks)
# Out:
#    tickType                             time   price   size  \
# 0         1 2025-07-07 10:54:00.663946+00:00  294.29  100.0
# 1         1 2025-07-07 10:54:00.663946+00:00  294.29  100.0
#
#                                       tickAttribLast  exchange  \
# 0  TickAttribLast(pastLimit=False, unreported=False)  DRCTEDGE
# 1  TickAttribLast(pastLimit=False, unreported=False)  DRCTEDGE
#
#   specialConditions
# 0                FT
# 1                FT

# %%
class DollarBars:
    def __init__(self,dollar_threshold=1_000_000):
        self.dollar_threshold = dollar_threshold
        self.bars = []
        self.new_bar = True
        self.current_dollar_amount = 0
        
    def on_new_tick(self,ticker:Ticker):
        for tick in ticker.tickByTicks:
            self.on_single_tick(tick)

    def on_single_tick(self,tick):
        if self.new_bar:
            self.current_dollar_amount+=(tick.size*tick.price)
            self.volume=tick.size
            self.open = self.high = self.low =  tick.price
            self.new_bar = False
        else:
            self.current_dollar_amount+=(tick.size*tick.price)
            self.volume+=tick.size
            self.high = max(self.high,tick.price)
            self.low = min(self.low,tick.price)
            
        if self.current_dollar_amount>=self.dollar_threshold:
            self.close = tick.price
            self.bars.append((self.open,self.high,self.low,self.close,self.volume))
            self.new_bar = True
            self.current_dollar_amount=0

# %% [markdown]
# # 🔁 Start Streaming Real Time Dollar Bars

# %%
dollar_bars = DollarBars()
ticker.updateEvent.clear()
ticker.updateEvent+=dollar_bars.on_new_tick

# %%
dollar_bars.current_dollar_amount
# Out:
# 0

# %%
dollar_bars.bars
# Out:
# [(294.56, 294.65, 294.5, 294.5, 3474.0), (294.5, 294.5, 294.3, 294.4, 3642.0)]
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
