# %% [markdown]
# <a href="https://colab.research.google.com/github/adidror005/youtube-videos/blob/main/Why_is_the_Market_Up_according_to_Llama_Index_using_Finviz_News_Headlines_Actual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Install Finviz Package, Llama Index

# %%
# !pip install finvizfinance
# !pip install llama_index
# Out:
# ...
#   Using cached finvizfinance-1.0.1-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached finvizfinance-1.0.1-py3-none-any.whl (44 kB)
# ...
#   Using cached llama_index-0.10.65-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached llama_index_agent_openai-0.2.9-py3-none-any.whl.metadata (729 bytes)
# ...
#   Using cached llama_index_cli-0.1.13-py3-none-any.whl.metadata (1.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 78.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 56.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.4/169.4 kB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 57.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 25.7 MB/s eta 0:00:00
# ...

# %%
from finvizfinance.news import News
fnews = News()

all_news = fnews.get_news()


all_news
# Out:
# {'news':        Date  ...                                               Link
#  0   09:15AM  ...  https://www.marketwatch.com/story/theres-no-wa...
#  1   09:11AM  ...  https://www.marketwatch.com/story/organigrams-...
#  2   09:07AM  ...                        https://www.wsj.com/finance
#  3   09:07AM  ...  https://www.marketwatch.com/livecoverage/stock...
#  4   09:05AM  ...  https://www.bloomberg.com/news/articles/2024-0...
#  ..      ...  ...                                                ...
#  85   Aug-12  ...  https://www.bloomberg.com/news/articles/2024-0...
#  86   Aug-12  ...  https://www.bloomberg.com/news/articles/2024-0...
#  87   Aug-12  ...  https://foxbusiness.com/politics/eu-regulator-...
#  88   Aug-12  ...  https://www.bloomberg.com/news/articles/2024-0...
#  89   Aug-12  ...  https://www.bloomberg.com/news/articles/2024-0...
#
#  [90 rows x 4 columns],
#  'blogs':        Date  ...                                               Link
# ...

# %%
all_news.keys()
# Out:
# dict_keys(['news', 'blogs'])

# %%
df_news = all_news['news']
df_news
# Out:
#        Date  ...                                               Link
# 0   09:15AM  ...  https://www.marketwatch.com/story/theres-no-wa...
# 1   09:11AM  ...  https://www.marketwatch.com/story/organigrams-...
# 2   09:07AM  ...                        https://www.wsj.com/finance
# 3   09:07AM  ...  https://www.marketwatch.com/livecoverage/stock...
# 4   09:05AM  ...  https://www.bloomberg.com/news/articles/2024-0...
# ..      ...  ...                                                ...
# 85   Aug-12  ...  https://www.bloomberg.com/news/articles/2024-0...
# 86   Aug-12  ...  https://www.bloomberg.com/news/articles/2024-0...
# 87   Aug-12  ...  https://foxbusiness.com/politics/eu-regulator-...
# 88   Aug-12  ...  https://www.bloomberg.com/news/articles/2024-0...
# 89   Aug-12  ...  https://www.bloomberg.com/news/articles/2024-0...
#
# [90 rows x 4 columns]

# %% [markdown]
# ### Llama Index Part
# * Imports + LLM Settings

# %%
import os
from google.colab import userdata
openai_api_key = userdata.get('OPENAI_API_KEY')

os.environ["OPENAI_API_KEY"] = openai_api_key
from llama_index.llms.openai import OpenAI
from llama_index.core import Settings
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader

Settings.llm = OpenAI(temperature=0, model="gpt-4")

# %% [markdown]
# * Create Documents and and make index and then query engine

# %%
from llama_index.core import Document
from llama_index.core import VectorStoreIndex


documents = df_news['Title'].tolist()

documents = [Document(text=text) for text in documents]

vector_index = VectorStoreIndex.from_documents(documents)

query_engine=vector_index.as_query_engine()

# %% [markdown]
# * Ask why the market is up?

# %%
response=query_engine.query("Why is the market up?")

# %%
print(response.response)
# Out:
# The market is up due to futures rising after a weaker-than-expected Producer Price Index (PPI).
