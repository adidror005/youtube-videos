# %% [markdown]
# <a href="https://colab.research.google.com/github/adidror005/youtube-videos/blob/main/Analyze_Company_Financials_With_Polygon_io_Actual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Polygon.IO
# * Polygon.IO is a super duper data platform [Polygon.IO](https://polygon.io/)
#
# * Go to Pricing and subscribe to Free Account
#     - 4 types of subscriptions for each Options, Stocks, Indices, Forex
#     - Free tier is good enough for a lot. 5 API calls max per minute
# * For docs go to docs / client library Python. See [Polygon.IO Docs](https://polygon.io/docs/stocks/getting-started)
#
# ### Prerequisite Video
#
# ### Get Historical Stock Data From Polygon.IO API (click to view)
#
#
# [![IMAGE ALT TEXT HERE](https://img.youtube.com/vi/6TeHBXbvkPI/0.jpg)](https://www.youtube.com/watch?v=6TeHBXbvkPI)
#
# ### Polygon.IO Playlist
#
# [![IMAGE ALT TEXT HERE](https://asset.brandfetch.io/idfGjoDDfo/idGLhETxky.png)](https://www.youtube.com/playlist?list=PLCZZtBmmgxn-QlbbMb-g-89GjHiml_AtS
# )

# %% [markdown]
# #### Install Client Library

# %%
# !pip install polygon-api-client
# Out:
# Requirement already satisfied: polygon-api-client in /usr/local/lib/python3.10/dist-packages (1.13.7)
# Requirement already satisfied: certifi<2025.0.0,>=2022.5.18 in /usr/local/lib/python3.10/dist-packages (from polygon-api-client) (2024.6.2)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.9 in /usr/local/lib/python3.10/dist-packages (from polygon-api-client) (1.26.19)
# Requirement already satisfied: websockets<13.0,>=10.3 in /usr/local/lib/python3.10/dist-packages (from polygon-api-client) (12.0)

# %% [markdown]
# ### API Key
# * Get in dashboard https://polygon.io/dashboard
# * Copy and paste here to MY_API_KEY. Note I did the "proper" thing by setting a secret, but this isn't necessary and you can just set MY_API_KEY to your API Key string

# %%
from google.colab import userdata
MY_API_KEY = userdata.get('POLYGON_API_KEY')

# %% [markdown]
# #### Connect to client

# %%
from polygon import RESTClient
client = RESTClient(MY_API_KEY)

# %% [markdown]
# ### Company Financials "Fundamental Data"
# #### Use *client.vx.list_stock_financials* to get OHLCV data for all stocks!
# * Pagenated so we should set limit to MAX_LIMIT=100 since free tier has 5 API calls per minute

# %%
help(client.vx.list_stock_financials)
# Out:
# Help on method list_stock_financials in module polygon.rest.vX:
#
# list_stock_financials(ticker: Optional[str] = None, cik: Optional[str] = None, company_name: Optional[str] = None, company_name_search: Optional[str] = None, sic: Optional[str] = None, filing_date: Union[str, int, datetime.datetime, datetime.date, NoneType] = None, filing_date_lt: Union[str, int, datetime.datetime, datetime.date, NoneType] = None, filing_date_lte: Union[str, int, datetime.datetime, datetime.date, NoneType] = None, filing_date_gt: Union[str, int, datetime.datetime, datetime.date, NoneType] = None, filing_date_gte: Union[str, int, datetime.datetime, datetime.date, NoneType] = None, period_of_report_date: Union[str, int, datetime.datetime, datetime.date, NoneType] = None, period_of_report_date_lt: Union[str, int, datetime.datetime, datetime.date, NoneType] = None, period_of_report_date_lte: Union[str, int, datetime.datetime, datetime.date, NoneType] = None, period_of_report_date_gt: Union[str, int, datetime.datetime, datetime.date, NoneType] = None, period_of_report_date_gte: Union[str, int, datetime.datetime, datetime.date, NoneType] = None, timeframe: Union[str, polygon.rest.models.common.Timeframe, NoneType] = None, include_sources: Optional[bool] = None, limit: Optional[int] = None, sort: Union[str, polygon.rest.models.common.Sort, NoneType] = None, order: Union[str, polygon.rest.models.common.Order, NoneType] = None, params: Optional[Dict[str, Any]] = None, raw: bool = False, options: Optional[polygon.rest.models.request.RequestOptionBuilder] = None) -> Union[Iterator[polygon.rest.models.financials.StockFinancial], urllib3.response.HTTPResponse] method of polygon.rest.vX.VXClient instance
#     Get historical financial data for a stock ticker.
#
#     :param ticker: Query by company ticker.
#     :param cik: Query by central index key (CIK) Number.
#     :param company_name: Query by company name.
#     :param company_name_search: Query by company name with partial-match text search.
#     :param sic: Query by standard industrial classification (SIC).
#     :param filing_date: Query by the date when the filing with financials data was filed in YYYY-MM-DD format.
#     :param filing_date_lt: filing_date less than.
#     :param filing_date_lte: filing_date less than or equal to.
#     :param filing_date_gt: filing_date greater than.
#     :param filing_date_gte: filing_date greater than or equal to.
#     :param period_of_report_date: The period of report for the period_of_report with financials data in YYYY-MM-DD format.
#     :param period_of_report_date_lt: period_of_report_date less than.
#     :param period_of_report_date_lte: period_of_report_date less than or equal to.
#     :param period_of_report_date_gt: period_of_report_date greater than.
#     :param period_of_report_date_gte: period_of_report_date greater than or equal to.
#     :param timeframe: Query by timeframe.
#     :param include_sources: Whether or not to include the xpath and formula attributes for each financial data point.
#     :param limit: Limit the number of results returned per-page, default is 10 and max is 100.
#     :param sort: Sort field used for ordering.
#     :param order: Order results based on the sort field.
#     :param params: Any additional query params
#     :param raw: Return raw object instead of results object
#     :return: Iterator of financials

# %%
import time
financials = []
MAX_LIMIT = 100
for f in client.vx.list_stock_financials(ticker='TSLA',filing_date_gte='2019-01-01',limit=MAX_LIMIT):
  financials.append(f)
  if (len(financials) % (MAX_LIMIT*5) == 0):
    time.sleep(60)
    print(f'sleeping for 60 seconds')

# %%
len(financials)
# Out:
# 22

# %% [markdown]
# ##### Turn into a dataframe for readability

# %%
import pandas as pd
df = pd.DataFrame(financials)
df.head()
# Out:
#           cik company_name    end_date filing_date  \
# 0  0001318605  Tesla, Inc.  2024-03-31  2024-04-24
# 1  0001318605  Tesla, Inc.  2023-12-31  2024-01-29
# 2  0001318605  Tesla, Inc.  2023-09-30  2023-10-23
# 3  0001318605  Tesla, Inc.  2023-06-30  2023-07-24
# 4  0001318605  Tesla, Inc.  2023-03-31  2023-04-24
#
#                                           financials fiscal_period  \
# 0  {'balance_sheet': {'other_current_assets': {'f...            Q1
# 1  {'balance_sheet': {'wages': {'formula': None, ...            FY
# 2  {'balance_sheet': {'accounts_payable': {'formu...            Q3
# 3  {'balance_sheet': {'noncurrent_liabilities': {...            Q2
# 4  {'balance_sheet': {'inventory': {'formula': No...            Q1
#
#   fiscal_year                             source_filing_file_url  \
# 0        2024  http://api.polygon.io/v1/reference/sec/filings...
# 1        2023  http://api.polygon.io/v1/reference/sec/filings...
# 2        2023  http://api.polygon.io/v1/reference/sec/filings...
# 3        2023  http://api.polygon.io/v1/reference/sec/filings...
# 4        2023  http://api.polygon.io/v1/reference/sec/filings...
#
#                                    source_filing_url  start_date
# 0  https://api.polygon.io/v1/reference/sec/filing...  2024-01-01
# 1  https://api.polygon.io/v1/reference/sec/filing...  2023-01-01
# 2  https://api.polygon.io/v1/reference/sec/filing...  2023-07-01
# 3  https://api.polygon.io/v1/reference/sec/filing...  2023-04-01
# 4  https://api.polygon.io/v1/reference/sec/filing...  2023-01-01

# %% [markdown]
# #### What does the "financials" column have?

# %%
financials_keys=list(df.financials.iloc[0].keys())
financials_keys
# Out:
# ['balance_sheet',
#  'cash_flow_statement',
#  'comprehensive_income',
#  'income_statement']

# %% [markdown]
# ### Let's parse them out
# * Note this isn't perfect and I am oversimplifying things because there can be different dicts with different keys...

# %%
for key in financials_keys:
  df[key] = df.financials.apply(lambda x: x[key])

# %%
df
# Out:
#            cik company_name    end_date filing_date  \
# 0   0001318605  Tesla, Inc.  2024-03-31  2024-04-24
# 1   0001318605  Tesla, Inc.  2023-12-31  2024-01-29
# 2   0001318605  Tesla, Inc.  2023-09-30  2023-10-23
# 3   0001318605  Tesla, Inc.  2023-06-30  2023-07-24
# 4   0001318605  Tesla, Inc.  2023-03-31  2023-04-24
# 5   0001318605  Tesla, Inc.  2022-12-31  2023-01-31
# 6   0001318605  Tesla, Inc.  2022-09-30  2022-10-24
# 7   0001318605  Tesla, Inc.  2022-06-30  2022-07-25
# 8   0001318605  Tesla, Inc.  2022-03-31  2022-04-25
# 9   0001318605  Tesla, Inc.  2021-12-31  2022-02-07
# 10  0001318605  Tesla, Inc.  2021-09-30  2021-10-25
# 11  0001318605  Tesla, Inc.  2021-06-30  2021-07-27
# 12  0001318605  Tesla, Inc.  2021-03-31  2021-04-28
# 13  0001318605  Tesla, Inc.  2020-12-31  2021-02-08
# 14  0001318605  Tesla, Inc.  2020-09-30  2020-10-26
# 15  0001318605  Tesla, Inc.  2020-06-30  2020-07-28
# 16  0001318605  Tesla, Inc.  2020-03-31  2020-04-30
# 17  0001318605  Tesla, Inc.  2019-12-31  2020-02-13
# 18  0001318605  Tesla, Inc.  2019-09-30  2019-10-29
# 19  0001318605  Tesla, Inc.  2019-06-30  2019-07-29
# 20  0001318605  Tesla, Inc.  2019-03-31  2019-04-29
# 21  0001318605  Tesla, Inc.  2018-12-31  2019-02-19
#
#                                            financials fiscal_period  \
# 0   {'balance_sheet': {'other_current_assets': {'f...            Q1
# 1   {'balance_sheet': {'wages': {'formula': None, ...            FY
# 2   {'balance_sheet': {'accounts_payable': {'formu...            Q3
# 3   {'balance_sheet': {'noncurrent_liabilities': {...            Q2
# 4   {'balance_sheet': {'inventory': {'formula': No...            Q1
# 5   {'balance_sheet': {'fixed_assets': {'formula':...            FY
# 6   {'balance_sheet': {'long_term_debt': {'formula...            Q3
# 7   {'balance_sheet': {'equity_attributable_to_non...            Q2
# 8   {'balance_sheet': {'long_term_debt': {'formula...            Q1
# 9   {'balance_sheet': {'other_noncurrent_assets': ...            FY
# 10  {'balance_sheet': {'long_term_debt': {'formula...            Q3
# 11  {'balance_sheet': {'wages': {'formula': None, ...            Q2
# 12  {'balance_sheet': {'inventory': {'formula': No...            Q1
# 13  {'balance_sheet': {'liabilities_and_equity': {...            FY
# 14  {'balance_sheet': {'liabilities': {'formula': ...            Q3
# 15  {'balance_sheet': {'equity': {'formula': None,...            Q2
# 16  {'balance_sheet': {'fixed_assets': {'formula':...            Q1
# 17  {'balance_sheet': {'other_current_liabilities'...            FY
# 18  {'balance_sheet': {'temporary_equity': {'formu...            Q3
# 19  {'balance_sheet': {'equity_attributable_to_non...            Q2
# 20  {'balance_sheet': {'inventory': {'formula': No...            Q1
# 21  {'balance_sheet': {'equity_attributable_to_par...            FY
#
#    fiscal_year                             source_filing_file_url  \
# 0         2024  http://api.polygon.io/v1/reference/sec/filings...
# 1         2023  http://api.polygon.io/v1/reference/sec/filings...
# 2         2023  http://api.polygon.io/v1/reference/sec/filings...
# 3         2023  http://api.polygon.io/v1/reference/sec/filings...
# 4         2023  http://api.polygon.io/v1/reference/sec/filings...
# 5         2022  http://api.polygon.io/v1/reference/sec/filings...
# 6         2022  http://api.polygon.io/v1/reference/sec/filings...
# 7         2022  http://api.polygon.io/v1/reference/sec/filings...
# 8         2022  http://api.polygon.io/v1/reference/sec/filings...
# 9         2021  http://api.polygon.io/v1/reference/sec/filings...
# 10        2021  http://api.polygon.io/v1/reference/sec/filings...
# 11        2021  http://api.polygon.io/v1/reference/sec/filings...
# 12        2021  http://api.polygon.io/v1/reference/sec/filings...
# 13        2020  http://api.polygon.io/v1/reference/sec/filings...
# 14        2020  http://api.polygon.io/v1/reference/sec/filings...
# 15        2020  http://api.polygon.io/v1/reference/sec/filings...
# 16        2020  http://api.polygon.io/v1/reference/sec/filings...
# 17        2019  http://api.polygon.io/v1/reference/sec/filings...
# 18        2019  http://api.polygon.io/v1/reference/sec/filings...
# 19        2019  http://api.polygon.io/v1/reference/sec/filings...
# 20        2019  http://api.polygon.io/v1/reference/sec/filings...
# 21        2018  http://api.polygon.io/v1/reference/sec/filings...
#
#                                     source_filing_url  start_date  \
# 0   https://api.polygon.io/v1/reference/sec/filing...  2024-01-01
# 1   https://api.polygon.io/v1/reference/sec/filing...  2023-01-01
# 2   https://api.polygon.io/v1/reference/sec/filing...  2023-07-01
# 3   https://api.polygon.io/v1/reference/sec/filing...  2023-04-01
# 4   https://api.polygon.io/v1/reference/sec/filing...  2023-01-01
# 5   https://api.polygon.io/v1/reference/sec/filing...  2022-01-01
# 6   https://api.polygon.io/v1/reference/sec/filing...  2022-07-01
# 7   https://api.polygon.io/v1/reference/sec/filing...  2022-04-01
# 8   https://api.polygon.io/v1/reference/sec/filing...  2022-01-01
# 9   https://api.polygon.io/v1/reference/sec/filing...  2021-01-01
# 10  https://api.polygon.io/v1/reference/sec/filing...  2021-07-01
# 11  https://api.polygon.io/v1/reference/sec/filing...  2021-04-01
# 12  https://api.polygon.io/v1/reference/sec/filing...  2021-01-01
# 13  https://api.polygon.io/v1/reference/sec/filing...  2020-01-01
# 14  https://api.polygon.io/v1/reference/sec/filing...  2020-07-01
# 15  https://api.polygon.io/v1/reference/sec/filing...  2020-04-01
# 16  https://api.polygon.io/v1/reference/sec/filing...  2020-01-01
# 17  https://api.polygon.io/v1/reference/sec/filing...  2019-01-01
# 18  https://api.polygon.io/v1/reference/sec/filing...  2019-07-01
# 19  https://api.polygon.io/v1/reference/sec/filing...  2019-04-01
# 20  https://api.polygon.io/v1/reference/sec/filing...  2019-01-01
# 21  https://api.polygon.io/v1/reference/sec/filing...  2018-01-01
#
#                                         balance_sheet  \
# 0   {'other_current_assets': {'formula': None, 'la...
# 1   {'wages': {'formula': None, 'label': 'Wages', ...
# 2   {'accounts_payable': {'formula': None, 'label'...
# 3   {'noncurrent_liabilities': {'formula': None, '...
# 4   {'inventory': {'formula': None, 'label': 'Inve...
# 5   {'fixed_assets': {'formula': None, 'label': 'F...
# 6   {'long_term_debt': {'formula': None, 'label': ...
# 7   {'equity_attributable_to_noncontrolling_intere...
# 8   {'long_term_debt': {'formula': None, 'label': ...
# 9   {'other_noncurrent_assets': {'formula': None, ...
# 10  {'long_term_debt': {'formula': None, 'label': ...
# 11  {'wages': {'formula': None, 'label': 'Wages', ...
# 12  {'inventory': {'formula': None, 'label': 'Inve...
# 13  {'liabilities_and_equity': {'formula': None, '...
# 14  {'liabilities': {'formula': None, 'label': 'Li...
# 15  {'equity': {'formula': None, 'label': 'Equity'...
# 16  {'fixed_assets': {'formula': None, 'label': 'F...
# 17  {'other_current_liabilities': {'formula': None...
# 18  {'temporary_equity': {'formula': None, 'label'...
# 19  {'equity_attributable_to_noncontrolling_intere...
# 20  {'inventory': {'formula': None, 'label': 'Inve...
# 21  {'equity_attributable_to_parent': {'formula': ...
#
#                                   cash_flow_statement  \
# 0   {'exchange_gains_losses': None, 'net_cash_flow...
# 1   {'exchange_gains_losses': None, 'net_cash_flow...
# 2   {'exchange_gains_losses': None, 'net_cash_flow...
# 3   {'exchange_gains_losses': None, 'net_cash_flow...
# 4   {'exchange_gains_losses': None, 'net_cash_flow...
# 5   {'exchange_gains_losses': None, 'net_cash_flow...
# 6   {'exchange_gains_losses': None, 'net_cash_flow...
# 7   {'exchange_gains_losses': None, 'net_cash_flow...
# 8   {'exchange_gains_losses': None, 'net_cash_flow...
# 9   {'exchange_gains_losses': None, 'net_cash_flow...
# 10  {'exchange_gains_losses': None, 'net_cash_flow...
# 11  {'exchange_gains_losses': None, 'net_cash_flow...
# 12  {'exchange_gains_losses': None, 'net_cash_flow...
# 13  {'exchange_gains_losses': None, 'net_cash_flow...
# 14  {'exchange_gains_losses': None, 'net_cash_flow...
# 15  {'exchange_gains_losses': None, 'net_cash_flow...
# 16  {'exchange_gains_losses': None, 'net_cash_flow...
# 17  {'exchange_gains_losses': None, 'net_cash_flow...
# 18  {'exchange_gains_losses': None, 'net_cash_flow...
# 19  {'exchange_gains_losses': None, 'net_cash_flow...
# 20  {'exchange_gains_losses': None, 'net_cash_flow...
# 21  {'exchange_gains_losses': None, 'net_cash_flow...
#
#                                  comprehensive_income  \
# 0   {'comprehensive_income_loss': {'formula': None...
# 1   {'comprehensive_income_loss': {'formula': None...
# 2   {'comprehensive_income_loss': {'formula': None...
# 3   {'comprehensive_income_loss': {'formula': None...
# 4   {'comprehensive_income_loss': {'formula': None...
# 5   {'comprehensive_income_loss': {'formula': None...
# 6   {'comprehensive_income_loss': {'formula': None...
# 7   {'comprehensive_income_loss': {'formula': None...
# 8   {'comprehensive_income_loss': {'formula': None...
# 9   {'comprehensive_income_loss': {'formula': None...
# 10  {'comprehensive_income_loss': {'formula': None...
# 11  {'comprehensive_income_loss': {'formula': None...
# 12  {'comprehensive_income_loss': {'formula': None...
# 13  {'comprehensive_income_loss': {'formula': None...
# 14  {'comprehensive_income_loss': {'formula': None...
# 15  {'comprehensive_income_loss': {'formula': None...
# 16  {'comprehensive_income_loss': {'formula': None...
# 17  {'comprehensive_income_loss': {'formula': None...
# 18  {'comprehensive_income_loss': {'formula': None...
# 19  {'comprehensive_income_loss': {'formula': None...
# 20  {'comprehensive_income_loss': {'formula': None...
# 21  {'comprehensive_income_loss': {'formula': None...
#
#                                      income_statement
# 0   {'basic_earnings_per_share': {'formula': None,...
# 1   {'basic_earnings_per_share': {'formula': None,...
# 2   {'basic_earnings_per_share': {'formula': None,...
# 3   {'basic_earnings_per_share': {'formula': None,...
# 4   {'basic_earnings_per_share': {'formula': None,...
# 5   {'basic_earnings_per_share': {'formula': None,...
# 6   {'basic_earnings_per_share': {'formula': None,...
# 7   {'basic_earnings_per_share': {'formula': None,...
# 8   {'basic_earnings_per_share': {'formula': None,...
# 9   {'basic_earnings_per_share': {'formula': None,...
# 10  {'basic_earnings_per_share': {'formula': None,...
# 11  {'basic_earnings_per_share': {'formula': None,...
# 12  {'basic_earnings_per_share': {'formula': None,...
# 13  {'basic_earnings_per_share': {'formula': None,...
# 14  {'basic_earnings_per_share': {'formula': None,...
# 15  {'basic_earnings_per_share': {'formula': None,...
# 16  {'basic_earnings_per_share': {'formula': None,...
# 17  {'basic_earnings_per_share': {'formula': None,...
# 18  {'basic_earnings_per_share': {'formula': None,...
# 19  {'basic_earnings_per_share': {'formula': None,...
# 20  {'basic_earnings_per_share': {'formula': None,...
# 21  {'basic_earnings_per_share': {'formula': None,...

# %% [markdown]
# ##### Example income_statement entry

# %%
df.income_statement.iloc[0]
# Out:
# {'basic_earnings_per_share': {'formula': None,
#   'label': 'Basic Earnings Per Share',
#   'order': 4200,
#   'unit': 'USD / shares',
#   'value': 0.37,
#   'xpath': None},
#  'cost_of_revenue': {'formula': None,
#   'label': 'Cost Of Revenue',
#   'order': 300,
#   'unit': 'USD',
#   'value': 17605000000.0,
#   'xpath': None},
#  'gross_profit': {'formula': None,
#   'label': 'Gross Profit',
#   'order': 800,
#   'unit': 'USD',
#   'value': 3696000000.0,
#   'xpath': None},
#  'operating_expenses': {'formula': None,
#   'label': 'Operating Expenses',
#   'order': 1000,
#   'unit': 'USD',
#   'value': 2525000000.0,
#   'xpath': None},
#  'revenues': {'formula': None,
#   'label': 'Revenues',
#   'order': 100,
#   'unit': 'USD',
#   'value': 21301000000.0,
#   'xpath': None}}

# %% [markdown]
# ### Let's see what keys each of these new columns has

# %%
from IPython.display import display, Markdown
for key in financials_keys:
  display(Markdown(f'### {key}'))
  print("\n".join(df[key].loc[0].keys()))
# Out:
# ### balance_sheet
# other_current_assets
# inventory
# long_term_debt
# wages
# current_liabilities
# other_noncurrent_liabilities
# assets
# equity_attributable_to_noncontrolling_interest
# redeemable_noncontrolling_interest
# equity
# liabilities
# intangible_assets
# accounts_payable
# liabilities_and_equity
# noncurrent_liabilities
# equity_attributable_to_parent
# temporary_equity
# noncurrent_assets
# other_current_liabilities
# fixed_assets
# current_assets
# other_noncurrent_assets
# ### cash_flow_statement
# exchange_gains_losses
# net_cash_flow
# net_cash_flow_from_financing_activities
# ### comprehensive_income
# comprehensive_income_loss
# comprehensive_income_loss_attributable_to_parent
# other_comprehensive_income_loss
# ### income_statement
# basic_earnings_per_share
# cost_of_revenue
# gross_profit
# operating_expenses
# revenues

# %% [markdown]
# ### Let's parse out things from the income statement

# %% [markdown]
# #### Note we need the 'value' field to get the values

# %%
for key in df['income_statement'].iloc[0].keys():
  df[key] = df.income_statement.apply(lambda x: x[key]['value'])
df
# Out:
#            cik company_name    end_date filing_date  \
# 0   0001318605  Tesla, Inc.  2024-03-31  2024-04-24
# 1   0001318605  Tesla, Inc.  2023-12-31  2024-01-29
# 2   0001318605  Tesla, Inc.  2023-09-30  2023-10-23
# 3   0001318605  Tesla, Inc.  2023-06-30  2023-07-24
# 4   0001318605  Tesla, Inc.  2023-03-31  2023-04-24
# 5   0001318605  Tesla, Inc.  2022-12-31  2023-01-31
# 6   0001318605  Tesla, Inc.  2022-09-30  2022-10-24
# 7   0001318605  Tesla, Inc.  2022-06-30  2022-07-25
# 8   0001318605  Tesla, Inc.  2022-03-31  2022-04-25
# 9   0001318605  Tesla, Inc.  2021-12-31  2022-02-07
# 10  0001318605  Tesla, Inc.  2021-09-30  2021-10-25
# 11  0001318605  Tesla, Inc.  2021-06-30  2021-07-27
# 12  0001318605  Tesla, Inc.  2021-03-31  2021-04-28
# 13  0001318605  Tesla, Inc.  2020-12-31  2021-02-08
# 14  0001318605  Tesla, Inc.  2020-09-30  2020-10-26
# 15  0001318605  Tesla, Inc.  2020-06-30  2020-07-28
# 16  0001318605  Tesla, Inc.  2020-03-31  2020-04-30
# 17  0001318605  Tesla, Inc.  2019-12-31  2020-02-13
# 18  0001318605  Tesla, Inc.  2019-09-30  2019-10-29
# 19  0001318605  Tesla, Inc.  2019-06-30  2019-07-29
# 20  0001318605  Tesla, Inc.  2019-03-31  2019-04-29
# 21  0001318605  Tesla, Inc.  2018-12-31  2019-02-19
#
#                                            financials fiscal_period  \
# 0   {'balance_sheet': {'other_current_assets': {'f...            Q1
# 1   {'balance_sheet': {'wages': {'formula': None, ...            FY
# 2   {'balance_sheet': {'accounts_payable': {'formu...            Q3
# 3   {'balance_sheet': {'noncurrent_liabilities': {...            Q2
# 4   {'balance_sheet': {'inventory': {'formula': No...            Q1
# 5   {'balance_sheet': {'fixed_assets': {'formula':...            FY
# 6   {'balance_sheet': {'long_term_debt': {'formula...            Q3
# 7   {'balance_sheet': {'equity_attributable_to_non...            Q2
# 8   {'balance_sheet': {'long_term_debt': {'formula...            Q1
# 9   {'balance_sheet': {'other_noncurrent_assets': ...            FY
# 10  {'balance_sheet': {'long_term_debt': {'formula...            Q3
# 11  {'balance_sheet': {'wages': {'formula': None, ...            Q2
# 12  {'balance_sheet': {'inventory': {'formula': No...            Q1
# 13  {'balance_sheet': {'liabilities_and_equity': {...            FY
# 14  {'balance_sheet': {'liabilities': {'formula': ...            Q3
# 15  {'balance_sheet': {'equity': {'formula': None,...            Q2
# 16  {'balance_sheet': {'fixed_assets': {'formula':...            Q1
# 17  {'balance_sheet': {'other_current_liabilities'...            FY
# 18  {'balance_sheet': {'temporary_equity': {'formu...            Q3
# 19  {'balance_sheet': {'equity_attributable_to_non...            Q2
# 20  {'balance_sheet': {'inventory': {'formula': No...            Q1
# 21  {'balance_sheet': {'equity_attributable_to_par...            FY
#
#    fiscal_year                             source_filing_file_url  \
# 0         2024  http://api.polygon.io/v1/reference/sec/filings...
# 1         2023  http://api.polygon.io/v1/reference/sec/filings...
# 2         2023  http://api.polygon.io/v1/reference/sec/filings...
# 3         2023  http://api.polygon.io/v1/reference/sec/filings...
# 4         2023  http://api.polygon.io/v1/reference/sec/filings...
# 5         2022  http://api.polygon.io/v1/reference/sec/filings...
# 6         2022  http://api.polygon.io/v1/reference/sec/filings...
# 7         2022  http://api.polygon.io/v1/reference/sec/filings...
# 8         2022  http://api.polygon.io/v1/reference/sec/filings...
# 9         2021  http://api.polygon.io/v1/reference/sec/filings...
# 10        2021  http://api.polygon.io/v1/reference/sec/filings...
# 11        2021  http://api.polygon.io/v1/reference/sec/filings...
# 12        2021  http://api.polygon.io/v1/reference/sec/filings...
# 13        2020  http://api.polygon.io/v1/reference/sec/filings...
# 14        2020  http://api.polygon.io/v1/reference/sec/filings...
# 15        2020  http://api.polygon.io/v1/reference/sec/filings...
# 16        2020  http://api.polygon.io/v1/reference/sec/filings...
# 17        2019  http://api.polygon.io/v1/reference/sec/filings...
# 18        2019  http://api.polygon.io/v1/reference/sec/filings...
# 19        2019  http://api.polygon.io/v1/reference/sec/filings...
# 20        2019  http://api.polygon.io/v1/reference/sec/filings...
# 21        2018  http://api.polygon.io/v1/reference/sec/filings...
#
#                                     source_filing_url  start_date  \
# 0   https://api.polygon.io/v1/reference/sec/filing...  2024-01-01
# 1   https://api.polygon.io/v1/reference/sec/filing...  2023-01-01
# 2   https://api.polygon.io/v1/reference/sec/filing...  2023-07-01
# 3   https://api.polygon.io/v1/reference/sec/filing...  2023-04-01
# 4   https://api.polygon.io/v1/reference/sec/filing...  2023-01-01
# 5   https://api.polygon.io/v1/reference/sec/filing...  2022-01-01
# 6   https://api.polygon.io/v1/reference/sec/filing...  2022-07-01
# 7   https://api.polygon.io/v1/reference/sec/filing...  2022-04-01
# 8   https://api.polygon.io/v1/reference/sec/filing...  2022-01-01
# 9   https://api.polygon.io/v1/reference/sec/filing...  2021-01-01
# 10  https://api.polygon.io/v1/reference/sec/filing...  2021-07-01
# 11  https://api.polygon.io/v1/reference/sec/filing...  2021-04-01
# 12  https://api.polygon.io/v1/reference/sec/filing...  2021-01-01
# 13  https://api.polygon.io/v1/reference/sec/filing...  2020-01-01
# 14  https://api.polygon.io/v1/reference/sec/filing...  2020-07-01
# 15  https://api.polygon.io/v1/reference/sec/filing...  2020-04-01
# 16  https://api.polygon.io/v1/reference/sec/filing...  2020-01-01
# 17  https://api.polygon.io/v1/reference/sec/filing...  2019-01-01
# 18  https://api.polygon.io/v1/reference/sec/filing...  2019-07-01
# 19  https://api.polygon.io/v1/reference/sec/filing...  2019-04-01
# 20  https://api.polygon.io/v1/reference/sec/filing...  2019-01-01
# 21  https://api.polygon.io/v1/reference/sec/filing...  2018-01-01
#
#                                         balance_sheet  \
# 0   {'other_current_assets': {'formula': None, 'la...
# 1   {'wages': {'formula': None, 'label': 'Wages', ...
# 2   {'accounts_payable': {'formula': None, 'label'...
# 3   {'noncurrent_liabilities': {'formula': None, '...
# 4   {'inventory': {'formula': None, 'label': 'Inve...
# 5   {'fixed_assets': {'formula': None, 'label': 'F...
# 6   {'long_term_debt': {'formula': None, 'label': ...
# 7   {'equity_attributable_to_noncontrolling_intere...
# 8   {'long_term_debt': {'formula': None, 'label': ...
# 9   {'other_noncurrent_assets': {'formula': None, ...
# 10  {'long_term_debt': {'formula': None, 'label': ...
# 11  {'wages': {'formula': None, 'label': 'Wages', ...
# 12  {'inventory': {'formula': None, 'label': 'Inve...
# 13  {'liabilities_and_equity': {'formula': None, '...
# 14  {'liabilities': {'formula': None, 'label': 'Li...
# 15  {'equity': {'formula': None, 'label': 'Equity'...
# 16  {'fixed_assets': {'formula': None, 'label': 'F...
# 17  {'other_current_liabilities': {'formula': None...
# 18  {'temporary_equity': {'formula': None, 'label'...
# 19  {'equity_attributable_to_noncontrolling_intere...
# 20  {'inventory': {'formula': None, 'label': 'Inve...
# 21  {'equity_attributable_to_parent': {'formula': ...
#
#                                   cash_flow_statement  \
# 0   {'exchange_gains_losses': None, 'net_cash_flow...
# 1   {'exchange_gains_losses': None, 'net_cash_flow...
# 2   {'exchange_gains_losses': None, 'net_cash_flow...
# 3   {'exchange_gains_losses': None, 'net_cash_flow...
# 4   {'exchange_gains_losses': None, 'net_cash_flow...
# 5   {'exchange_gains_losses': None, 'net_cash_flow...
# 6   {'exchange_gains_losses': None, 'net_cash_flow...
# 7   {'exchange_gains_losses': None, 'net_cash_flow...
# 8   {'exchange_gains_losses': None, 'net_cash_flow...
# 9   {'exchange_gains_losses': None, 'net_cash_flow...
# 10  {'exchange_gains_losses': None, 'net_cash_flow...
# 11  {'exchange_gains_losses': None, 'net_cash_flow...
# 12  {'exchange_gains_losses': None, 'net_cash_flow...
# 13  {'exchange_gains_losses': None, 'net_cash_flow...
# 14  {'exchange_gains_losses': None, 'net_cash_flow...
# 15  {'exchange_gains_losses': None, 'net_cash_flow...
# 16  {'exchange_gains_losses': None, 'net_cash_flow...
# 17  {'exchange_gains_losses': None, 'net_cash_flow...
# 18  {'exchange_gains_losses': None, 'net_cash_flow...
# 19  {'exchange_gains_losses': None, 'net_cash_flow...
# 20  {'exchange_gains_losses': None, 'net_cash_flow...
# 21  {'exchange_gains_losses': None, 'net_cash_flow...
#
#                                  comprehensive_income  \
# 0   {'comprehensive_income_loss': {'formula': None...
# 1   {'comprehensive_income_loss': {'formula': None...
# 2   {'comprehensive_income_loss': {'formula': None...
# 3   {'comprehensive_income_loss': {'formula': None...
# 4   {'comprehensive_income_loss': {'formula': None...
# 5   {'comprehensive_income_loss': {'formula': None...
# 6   {'comprehensive_income_loss': {'formula': None...
# 7   {'comprehensive_income_loss': {'formula': None...
# 8   {'comprehensive_income_loss': {'formula': None...
# 9   {'comprehensive_income_loss': {'formula': None...
# 10  {'comprehensive_income_loss': {'formula': None...
# 11  {'comprehensive_income_loss': {'formula': None...
# 12  {'comprehensive_income_loss': {'formula': None...
# 13  {'comprehensive_income_loss': {'formula': None...
# 14  {'comprehensive_income_loss': {'formula': None...
# 15  {'comprehensive_income_loss': {'formula': None...
# 16  {'comprehensive_income_loss': {'formula': None...
# 17  {'comprehensive_income_loss': {'formula': None...
# 18  {'comprehensive_income_loss': {'formula': None...
# 19  {'comprehensive_income_loss': {'formula': None...
# 20  {'comprehensive_income_loss': {'formula': None...
# 21  {'comprehensive_income_loss': {'formula': None...
#
#                                      income_statement  \
# 0   {'basic_earnings_per_share': {'formula': None,...
# 1   {'basic_earnings_per_share': {'formula': None,...
# 2   {'basic_earnings_per_share': {'formula': None,...
# 3   {'basic_earnings_per_share': {'formula': None,...
# 4   {'basic_earnings_per_share': {'formula': None,...
# 5   {'basic_earnings_per_share': {'formula': None,...
# 6   {'basic_earnings_per_share': {'formula': None,...
# 7   {'basic_earnings_per_share': {'formula': None,...
# 8   {'basic_earnings_per_share': {'formula': None,...
# 9   {'basic_earnings_per_share': {'formula': None,...
# 10  {'basic_earnings_per_share': {'formula': None,...
# 11  {'basic_earnings_per_share': {'formula': None,...
# 12  {'basic_earnings_per_share': {'formula': None,...
# 13  {'basic_earnings_per_share': {'formula': None,...
# 14  {'basic_earnings_per_share': {'formula': None,...
# 15  {'basic_earnings_per_share': {'formula': None,...
# 16  {'basic_earnings_per_share': {'formula': None,...
# 17  {'basic_earnings_per_share': {'formula': None,...
# 18  {'basic_earnings_per_share': {'formula': None,...
# 19  {'basic_earnings_per_share': {'formula': None,...
# 20  {'basic_earnings_per_share': {'formula': None,...
# 21  {'basic_earnings_per_share': {'formula': None,...
#
#     basic_earnings_per_share  cost_of_revenue  gross_profit  \
# 0                       0.37     1.760500e+10  3.696000e+09
# 1                       4.73     7.911300e+10  1.766000e+10
# 2                       0.58     1.917200e+10  4.178000e+09
# 3                       0.85     2.039400e+10  4.533000e+09
# 4                       0.80     1.881800e+10  4.511000e+09
# 5                       4.02     6.060900e+10  2.085300e+10
# 6                       1.05     1.607200e+10  5.382000e+09
# 7                       2.18     1.270000e+10  4.234000e+09
# 8                       3.20     1.329600e+10  5.460000e+09
# 9                       5.60     4.021700e+10  1.360600e+10
# 10                      1.62     1.009700e+10  3.660000e+09
# 11                      1.18     9.074000e+09  2.884000e+09
# 12                      0.46     8.174000e+09  2.215000e+09
# 13                      0.74     2.490600e+10  6.630000e+09
# 14                      0.32     6.708000e+09  2.063000e+09
# 15                      0.56     4.769000e+09  1.267000e+09
# 16                      0.09     4.751000e+09  1.234000e+09
# 17                     -4.92     2.050900e+10  4.069000e+09
# 18                      0.80     5.112000e+09  1.191000e+09
# 19                     -2.31     5.428630e+09  9.210000e+08
# 20                     -4.10     3.975721e+09  5.660000e+08
# 21                     -5.72     1.741925e+10  4.042021e+09
#
#     operating_expenses      revenues
# 0         2.525000e+09  2.130100e+10
# 1         8.769000e+09  9.677300e+10
# 2         2.414000e+09  2.335000e+10
# 3         2.134000e+09  2.492700e+10
# 4         1.847000e+09  2.332900e+10
# 5         7.197000e+09  8.146200e+10
# 6         1.694000e+09  2.145400e+10
# 7         1.770000e+09  1.693400e+10
# 8         1.857000e+09  1.875600e+10
# 9         7.083000e+09  5.382300e+10
# 10        1.656000e+09  1.375700e+10
# 11        1.572000e+09  1.195800e+10
# 12        1.621000e+09  1.038900e+10
# 13        4.636000e+09  3.153600e+10
# 14        1.254000e+09  8.771000e+09
# 15        9.400000e+08  6.036000e+09
# 16        9.510000e+08  5.985000e+09
# 17        4.138000e+09  2.457800e+10
# 18        9.300000e+08  6.303000e+09
# 19        1.088504e+09  6.350000e+09
# 20        1.087574e+09  4.541000e+09
# 21        4.430094e+09  2.146127e+10

# %% [markdown]
# ### Plot Quarterly EPS,Revenue, and Gross Profit Over Time

# %%
quarterly_financials = df[df.fiscal_period.str.contains('Q')]
quarterly_financials
# Out:
#            cik company_name    end_date filing_date  \
# 0   0001318605  Tesla, Inc.  2024-03-31  2024-04-24
# 2   0001318605  Tesla, Inc.  2023-09-30  2023-10-23
# 3   0001318605  Tesla, Inc.  2023-06-30  2023-07-24
# 4   0001318605  Tesla, Inc.  2023-03-31  2023-04-24
# 6   0001318605  Tesla, Inc.  2022-09-30  2022-10-24
# 7   0001318605  Tesla, Inc.  2022-06-30  2022-07-25
# 8   0001318605  Tesla, Inc.  2022-03-31  2022-04-25
# 10  0001318605  Tesla, Inc.  2021-09-30  2021-10-25
# 11  0001318605  Tesla, Inc.  2021-06-30  2021-07-27
# 12  0001318605  Tesla, Inc.  2021-03-31  2021-04-28
# 14  0001318605  Tesla, Inc.  2020-09-30  2020-10-26
# 15  0001318605  Tesla, Inc.  2020-06-30  2020-07-28
# 16  0001318605  Tesla, Inc.  2020-03-31  2020-04-30
# 18  0001318605  Tesla, Inc.  2019-09-30  2019-10-29
# 19  0001318605  Tesla, Inc.  2019-06-30  2019-07-29
# 20  0001318605  Tesla, Inc.  2019-03-31  2019-04-29
#
#                                            financials fiscal_period  \
# 0   {'balance_sheet': {'other_current_assets': {'f...            Q1
# 2   {'balance_sheet': {'accounts_payable': {'formu...            Q3
# 3   {'balance_sheet': {'noncurrent_liabilities': {...            Q2
# 4   {'balance_sheet': {'inventory': {'formula': No...            Q1
# 6   {'balance_sheet': {'long_term_debt': {'formula...            Q3
# 7   {'balance_sheet': {'equity_attributable_to_non...            Q2
# 8   {'balance_sheet': {'long_term_debt': {'formula...            Q1
# 10  {'balance_sheet': {'long_term_debt': {'formula...            Q3
# 11  {'balance_sheet': {'wages': {'formula': None, ...            Q2
# 12  {'balance_sheet': {'inventory': {'formula': No...            Q1
# 14  {'balance_sheet': {'liabilities': {'formula': ...            Q3
# 15  {'balance_sheet': {'equity': {'formula': None,...            Q2
# 16  {'balance_sheet': {'fixed_assets': {'formula':...            Q1
# 18  {'balance_sheet': {'temporary_equity': {'formu...            Q3
# 19  {'balance_sheet': {'equity_attributable_to_non...            Q2
# 20  {'balance_sheet': {'inventory': {'formula': No...            Q1
#
#    fiscal_year                             source_filing_file_url  \
# 0         2024  http://api.polygon.io/v1/reference/sec/filings...
# 2         2023  http://api.polygon.io/v1/reference/sec/filings...
# 3         2023  http://api.polygon.io/v1/reference/sec/filings...
# 4         2023  http://api.polygon.io/v1/reference/sec/filings...
# 6         2022  http://api.polygon.io/v1/reference/sec/filings...
# 7         2022  http://api.polygon.io/v1/reference/sec/filings...
# 8         2022  http://api.polygon.io/v1/reference/sec/filings...
# 10        2021  http://api.polygon.io/v1/reference/sec/filings...
# 11        2021  http://api.polygon.io/v1/reference/sec/filings...
# 12        2021  http://api.polygon.io/v1/reference/sec/filings...
# 14        2020  http://api.polygon.io/v1/reference/sec/filings...
# 15        2020  http://api.polygon.io/v1/reference/sec/filings...
# 16        2020  http://api.polygon.io/v1/reference/sec/filings...
# 18        2019  http://api.polygon.io/v1/reference/sec/filings...
# 19        2019  http://api.polygon.io/v1/reference/sec/filings...
# 20        2019  http://api.polygon.io/v1/reference/sec/filings...
#
#                                     source_filing_url  start_date  \
# 0   https://api.polygon.io/v1/reference/sec/filing...  2024-01-01
# 2   https://api.polygon.io/v1/reference/sec/filing...  2023-07-01
# 3   https://api.polygon.io/v1/reference/sec/filing...  2023-04-01
# 4   https://api.polygon.io/v1/reference/sec/filing...  2023-01-01
# 6   https://api.polygon.io/v1/reference/sec/filing...  2022-07-01
# 7   https://api.polygon.io/v1/reference/sec/filing...  2022-04-01
# 8   https://api.polygon.io/v1/reference/sec/filing...  2022-01-01
# 10  https://api.polygon.io/v1/reference/sec/filing...  2021-07-01
# 11  https://api.polygon.io/v1/reference/sec/filing...  2021-04-01
# 12  https://api.polygon.io/v1/reference/sec/filing...  2021-01-01
# 14  https://api.polygon.io/v1/reference/sec/filing...  2020-07-01
# 15  https://api.polygon.io/v1/reference/sec/filing...  2020-04-01
# 16  https://api.polygon.io/v1/reference/sec/filing...  2020-01-01
# 18  https://api.polygon.io/v1/reference/sec/filing...  2019-07-01
# 19  https://api.polygon.io/v1/reference/sec/filing...  2019-04-01
# 20  https://api.polygon.io/v1/reference/sec/filing...  2019-01-01
#
#                                         balance_sheet  \
# 0   {'other_current_assets': {'formula': None, 'la...
# 2   {'accounts_payable': {'formula': None, 'label'...
# 3   {'noncurrent_liabilities': {'formula': None, '...
# 4   {'inventory': {'formula': None, 'label': 'Inve...
# 6   {'long_term_debt': {'formula': None, 'label': ...
# 7   {'equity_attributable_to_noncontrolling_intere...
# 8   {'long_term_debt': {'formula': None, 'label': ...
# 10  {'long_term_debt': {'formula': None, 'label': ...
# 11  {'wages': {'formula': None, 'label': 'Wages', ...
# 12  {'inventory': {'formula': None, 'label': 'Inve...
# 14  {'liabilities': {'formula': None, 'label': 'Li...
# 15  {'equity': {'formula': None, 'label': 'Equity'...
# 16  {'fixed_assets': {'formula': None, 'label': 'F...
# 18  {'temporary_equity': {'formula': None, 'label'...
# 19  {'equity_attributable_to_noncontrolling_intere...
# 20  {'inventory': {'formula': None, 'label': 'Inve...
#
#                                   cash_flow_statement  \
# 0   {'exchange_gains_losses': None, 'net_cash_flow...
# 2   {'exchange_gains_losses': None, 'net_cash_flow...
# 3   {'exchange_gains_losses': None, 'net_cash_flow...
# 4   {'exchange_gains_losses': None, 'net_cash_flow...
# 6   {'exchange_gains_losses': None, 'net_cash_flow...
# 7   {'exchange_gains_losses': None, 'net_cash_flow...
# 8   {'exchange_gains_losses': None, 'net_cash_flow...
# 10  {'exchange_gains_losses': None, 'net_cash_flow...
# 11  {'exchange_gains_losses': None, 'net_cash_flow...
# 12  {'exchange_gains_losses': None, 'net_cash_flow...
# 14  {'exchange_gains_losses': None, 'net_cash_flow...
# 15  {'exchange_gains_losses': None, 'net_cash_flow...
# 16  {'exchange_gains_losses': None, 'net_cash_flow...
# 18  {'exchange_gains_losses': None, 'net_cash_flow...
# 19  {'exchange_gains_losses': None, 'net_cash_flow...
# 20  {'exchange_gains_losses': None, 'net_cash_flow...
#
#                                  comprehensive_income  \
# 0   {'comprehensive_income_loss': {'formula': None...
# 2   {'comprehensive_income_loss': {'formula': None...
# 3   {'comprehensive_income_loss': {'formula': None...
# 4   {'comprehensive_income_loss': {'formula': None...
# 6   {'comprehensive_income_loss': {'formula': None...
# 7   {'comprehensive_income_loss': {'formula': None...
# 8   {'comprehensive_income_loss': {'formula': None...
# 10  {'comprehensive_income_loss': {'formula': None...
# 11  {'comprehensive_income_loss': {'formula': None...
# 12  {'comprehensive_income_loss': {'formula': None...
# 14  {'comprehensive_income_loss': {'formula': None...
# 15  {'comprehensive_income_loss': {'formula': None...
# 16  {'comprehensive_income_loss': {'formula': None...
# 18  {'comprehensive_income_loss': {'formula': None...
# 19  {'comprehensive_income_loss': {'formula': None...
# 20  {'comprehensive_income_loss': {'formula': None...
#
#                                      income_statement  \
# 0   {'basic_earnings_per_share': {'formula': None,...
# 2   {'basic_earnings_per_share': {'formula': None,...
# 3   {'basic_earnings_per_share': {'formula': None,...
# 4   {'basic_earnings_per_share': {'formula': None,...
# 6   {'basic_earnings_per_share': {'formula': None,...
# 7   {'basic_earnings_per_share': {'formula': None,...
# 8   {'basic_earnings_per_share': {'formula': None,...
# 10  {'basic_earnings_per_share': {'formula': None,...
# 11  {'basic_earnings_per_share': {'formula': None,...
# 12  {'basic_earnings_per_share': {'formula': None,...
# 14  {'basic_earnings_per_share': {'formula': None,...
# 15  {'basic_earnings_per_share': {'formula': None,...
# 16  {'basic_earnings_per_share': {'formula': None,...
# 18  {'basic_earnings_per_share': {'formula': None,...
# 19  {'basic_earnings_per_share': {'formula': None,...
# 20  {'basic_earnings_per_share': {'formula': None,...
#
#     basic_earnings_per_share  cost_of_revenue  gross_profit  \
# 0                       0.37     1.760500e+10  3.696000e+09
# 2                       0.58     1.917200e+10  4.178000e+09
# 3                       0.85     2.039400e+10  4.533000e+09
# 4                       0.80     1.881800e+10  4.511000e+09
# 6                       1.05     1.607200e+10  5.382000e+09
# 7                       2.18     1.270000e+10  4.234000e+09
# 8                       3.20     1.329600e+10  5.460000e+09
# 10                      1.62     1.009700e+10  3.660000e+09
# 11                      1.18     9.074000e+09  2.884000e+09
# 12                      0.46     8.174000e+09  2.215000e+09
# 14                      0.32     6.708000e+09  2.063000e+09
# 15                      0.56     4.769000e+09  1.267000e+09
# 16                      0.09     4.751000e+09  1.234000e+09
# 18                      0.80     5.112000e+09  1.191000e+09
# 19                     -2.31     5.428630e+09  9.210000e+08
# 20                     -4.10     3.975721e+09  5.660000e+08
#
#     operating_expenses      revenues
# 0         2.525000e+09  2.130100e+10
# 2         2.414000e+09  2.335000e+10
# 3         2.134000e+09  2.492700e+10
# 4         1.847000e+09  2.332900e+10
# 6         1.694000e+09  2.145400e+10
# 7         1.770000e+09  1.693400e+10
# 8         1.857000e+09  1.875600e+10
# 10        1.656000e+09  1.375700e+10
# 11        1.572000e+09  1.195800e+10
# 12        1.621000e+09  1.038900e+10
# 14        1.254000e+09  8.771000e+09
# 15        9.400000e+08  6.036000e+09
# 16        9.510000e+08  5.985000e+09
# 18        9.300000e+08  6.303000e+09
# 19        1.088504e+09  6.350000e+09
# 20        1.087574e+09  4.541000e+09

# %% [markdown]
# ### Convert to tall format for plotly express using Pandas Melt

# %% [markdown]
# ##### Let's use pandas' melt function to convert to a tall format so we can use plotly express
# * Instead of columns gross_profit, revenue, basic_earnings_per_share as seperate columns we want one column with all these values and a variable called measurement_type which will take values in ['gross_profit','revenues','basic_earnings_per_share']

# %%
quarterly_financials_tall=quarterly_financials.melt(id_vars=['start_date','end_date'],value_vars=['gross_profit','revenues','basic_earnings_per_share','operating_expenses'],var_name='Financial Metric',value_name='Dollars')

# %% [markdown]
# ### Plot these 3 measurements with plotly express

# %%
import plotly.express as px

fig = px.line(quarterly_financials_tall,x='start_date',y='Dollars',facet_col='Financial Metric',facet_col_wrap=1,height=800)

fig.update_yaxes(matches=None)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b9d475da-2d8c-453d-b4ec-33e05838582f" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9d475da-2d8c-453d-b4ec-33e05838582f")) {                    Plotly.newPlot(                        "b9d475da-2d8c-453d-b4ec-33e05838582f",                        [{"hovertemplate":"Financial Metric=gross_profit\u003cbr\u003estart_date=%{x}\u003cbr\u003eDollars=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2024-01-01","2023-07-01","2023-04-01","2023-01-01","2022-07-01","2022-04-01","2022-01-01","2021-07-01","2021-04-01","2021-01-01","2020-07-01","2020-04-01","2020-01-01","2019-07-01","2019-04-01","2019-01-01"],"xaxis":"x4","y":[3696000000.0,4178000000.0,4533000000.0,4511000000.0,5382000000.0,4234000000.0,5460000000.0,3660000000.0,2884000000.0,2215000000.0,2063000000.0,1267000000.0,1234000000.0,1191000000.0,921000000.0,566000000.0],"yaxis":"y4","type":"scatter"},{"hovertemplate":"Financial Metric=revenues\u003cbr\u003estart_date=%{x}\u003cbr\u003eDollars=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2024-01-01","2023-07-01","2023-04-01","2023-01-01","2022-07-01","2022-04-01","2022-01-01","2021-07-01","2021-04-01","2021-01-01","2020-07-01","2020-04-01","2020-01-01","2019-07-01","2019-04-01","2019-01-01"],"xaxis":"x3","y":[21301000000.0,23350000000.0,24927000000.0,23329000000.0,21454000000.0,16934000000.0,18756000000.0,13757000000.0,11958000000.0,10389000000.0,8771000000.0,6036000000.0,5985000000.0,6303000000.0,6350000000.0,4541000000.0],"yaxis":"y3","type":"scatter"},{"hovertemplate":"Financial Metric=basic_earnings_per_share\u003cbr\u003estart_date=%{x}\u003cbr\u003eDollars=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2024-01-01","2023-07-01","2023-04-01","2023-01-01","2022-07-01","2022-04-01","2022-01-01","2021-07-01","2021-04-01","2021-01-01","2020-07-01","2020-04-01","2020-01-01","2019-07-01","2019-04-01","2019-01-01"],"xaxis":"x2","y":[0.37,0.58,0.85,0.8,1.05,2.18,3.2,1.62,1.18,0.46,0.32,0.56,0.09,0.8,-2.31,-4.1],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Financial Metric=operating_expenses\u003cbr\u003estart_date=%{x}\u003cbr\u003eDollars=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2024-01-01","2023-07-01","2023-04-01","2023-01-01","2022-07-01","2022-04-01","2022-01-01","2021-07-01","2021-04-01","2021-01-01","2020-07-01","2020-04-01","2020-01-01","2019-07-01","2019-04-01","2019-01-01"],"xaxis":"x","y":[2525000000.0,2414000000.0,2134000000.0,1847000000.0,1694000000.0,1770000000.0,1857000000.0,1656000000.0,1572000000.0,1621000000.0,1254000000.0,940000000.0,951000000.0,930000000.0,1088504000.0,1087574000.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"ou ...

# %% [markdown]
# ### Let's Add Nvidia so we can compare
# * First let's wrap all the parsing above in a function

# %%
def get_quarterly_financials(symbol):
    financials = []
    MAX_LIMIT = 100
    for f in client.vx.list_stock_financials(symbol,filing_date_gte='2019-01-01',limit=MAX_LIMIT):
        financials.append(f)
        if len(financials) % (5*MAX_LIMIT) == 0:
            time.sleep(60)
    df_financials = pd.DataFrame(financials)
    financials_keys=list(df_financials.financials.iloc[0].keys())
    for key in financials_keys:
        df_financials[key]=df_financials.financials.apply(lambda l:l[key])
    for key in df_financials['income_statement'].iloc[0].keys():
        df_financials[key]=df_financials['income_statement'].apply(lambda l:l[key]['value'])
    quarterly_financials=df_financials[df_financials.fiscal_period.str.contains('Q')]
    quarterly_financials_tall=quarterly_financials.melt(id_vars=['start_date','end_date'],
                                                    value_vars=['gross_profit','revenues','basic_earnings_per_share','operating_expenses'],
                                                    var_name='Financial Metric',value_name='Dollars')
    return quarterly_financials_tall

# %%
quarterly_financials_NVDA = get_quarterly_financials('NVDA')

# %%
quarterly_financials_NVDA
# Out:
#     start_date    end_date    Financial Metric       Dollars
# 0   2024-01-29  2024-04-28        gross_profit  2.040600e+10
# 1   2023-07-31  2023-10-29        gross_profit  1.340000e+10
# 2   2023-05-01  2023-07-30        gross_profit  9.462000e+09
# 3   2023-01-30  2023-04-30        gross_profit  4.648000e+09
# 4   2022-08-01  2022-10-30        gross_profit  3.177000e+09
# ..         ...         ...                 ...           ...
# 59  2020-04-27  2020-07-26  operating_expenses  1.624000e+09
# 60  2020-01-27  2020-04-26  operating_expenses  1.028000e+09
# 61  2019-07-29  2019-10-27  operating_expenses  9.890000e+08
# 62  2019-04-29  2019-07-28  operating_expenses  9.700000e+08
# 63  2019-01-28  2019-04-28  operating_expenses  9.380000e+08
#
# [64 rows x 4 columns]

# %% [markdown]
# ### Combine with TSLA for comparison

# %%
quarterly_financials_NVDA_TSLA = pd.concat([quarterly_financials_NVDA.assign(symbol='NVDA'),quarterly_financials_tall.assign(symbol='TSLA')])

# %%
quarterly_financials_NVDA_TSLA
# Out:
#     start_date    end_date    Financial Metric       Dollars symbol
# 0   2024-01-29  2024-04-28        gross_profit  2.040600e+10   NVDA
# 1   2023-07-31  2023-10-29        gross_profit  1.340000e+10   NVDA
# 2   2023-05-01  2023-07-30        gross_profit  9.462000e+09   NVDA
# 3   2023-01-30  2023-04-30        gross_profit  4.648000e+09   NVDA
# 4   2022-08-01  2022-10-30        gross_profit  3.177000e+09   NVDA
# ..         ...         ...                 ...           ...    ...
# 59  2020-04-01  2020-06-30  operating_expenses  9.400000e+08   TSLA
# 60  2020-01-01  2020-03-31  operating_expenses  9.510000e+08   TSLA
# 61  2019-07-01  2019-09-30  operating_expenses  9.300000e+08   TSLA
# 62  2019-04-01  2019-06-30  operating_expenses  1.088504e+09   TSLA
# 63  2019-01-01  2019-03-31  operating_expenses  1.087574e+09   TSLA
#
# [128 rows x 5 columns]

# %%
import plotly.express as px

fig = px.line(quarterly_financials_NVDA_TSLA,x='start_date',y='Dollars',facet_col='Financial Metric',color='symbol',facet_col_wrap=2,height=800,width=1000,title='TSLA vs NVDA Financials',
              facet_col_spacing=0.1,  # Adjust column spacing
              facet_row_spacing=0.1)  # Adjust row spacing


fig.update_yaxes(matches=None)

# Custom titles for each facet
custom_titles = {
    'Financial Metric=revenues': 'Revenue',
    'Financial Metric=gross_profit': 'Gross Profit',
    'Financial Metric=basic_earnings_per_share': 'Earnings Per Share',
    'Financial Metric=operating_expenses': 'Operating Expenses'
}

fig.for_each_annotation(lambda a: a.update(text=custom_titles.get(a.text, a.text)))

# Ensure all x-axes show tick labels
for i in range(len(fig.layout.annotations)):
    fig.layout[f'xaxis{i+1}'].showticklabels = True

# Ensure all x-axes show tick labels
for i in range(len(fig.layout.annotations)):
    fig.layout[f'xaxis{i+1}'].showticklabels = True

# Ensure all y-axes show tick labels
for i in range(len(fig.layout.annotations)):
    fig.layout[f'yaxis{i+1}'].showticklabels = True



# Center the title and make it larger
fig.update_layout(
    title={
        'text': "TSLA vs NVDA Financials",
        'y': 0.95,
        'x': 0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font': {
            'size': 24
        }
    }
)




fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9ea76c44-8513-4c00-9674-f8ec92c35f50" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ea76c44-8513-4c00-9674-f8ec92c35f50")) {                    Plotly.newPlot(                        "9ea76c44-8513-4c00-9674-f8ec92c35f50",                        [{"hovertemplate":"symbol=NVDA\u003cbr\u003eFinancial Metric=gross_profit\u003cbr\u003estart_date=%{x}\u003cbr\u003eDollars=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NVDA","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"NVDA","orientation":"v","showlegend":true,"x":["2024-01-29","2023-07-31","2023-05-01","2023-01-30","2022-08-01","2022-05-02","2022-01-31","2021-08-02","2021-05-03","2021-02-01","2020-07-27","2020-04-27","2020-01-27","2019-07-29","2019-04-29","2019-01-28"],"xaxis":"x3","y":[20406000000.0,13400000000.0,9462000000.0,4648000000.0,3177000000.0,2915000000.0,5431000000.0,4631000000.0,4215000000.0,3629000000.0,2960000000.0,2275000000.0,2004000000.0,1916000000.0,1541000000.0,1296000000.0],"yaxis":"y3","type":"scatter"},{"hovertemplate":"symbol=NVDA\u003cbr\u003eFinancial Metric=revenues\u003cbr\u003estart_date=%{x}\u003cbr\u003eDollars=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NVDA","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"NVDA","orientation":"v","showlegend":false,"x":["2024-01-29","2023-07-31","2023-05-01","2023-01-30","2022-08-01","2022-05-02","2022-01-31","2021-08-02","2021-05-03","2021-02-01","2020-07-27","2020-04-27","2020-01-27","2019-07-29","2019-04-29","2019-01-28"],"xaxis":"x4","y":[26044000000.0,18120000000.0,13507000000.0,7192000000.0,5931000000.0,6704000000.0,8288000000.0,7103000000.0,6507000000.0,5661000000.0,4726000000.0,3866000000.0,3080000000.0,3014000000.0,2579000000.0,2220000000.0],"yaxis":"y4","type":"scatter"},{"hovertemplate":"symbol=NVDA\u003cbr\u003eFinancial Metric=basic_earnings_per_share\u003cbr\u003estart_date=%{x}\u003cbr\u003eDollars=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NVDA","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"NVDA","orientation":"v","showlegend":false,"x":["2024-01-29","2023-07-31","2023-05-01","2023-01-30","2022-08-01","2022-05-02","2022-01-31","2021-08-02","2021-05-03","2021-02-01","2020-07-27","2020-04-27","2020-01-27","2019-07-29","2019-04-29","2019-01-28"],"xaxis":"x","y":[6.04,3.75,2.5,0.83,0.27,0.26,0.65,0.99,0.95,3.08,2.16,1.01,1.49,1.47,0.91,0.65],"yaxis":"y","type":"scatter"},{"hovertemplate":"symbol=NVDA\u003cbr\u003eFinancial Metric=operating_expenses\u003cbr\u003estart_date=%{x}\u003cbr\u003eDollars=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NVDA","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"NVDA","orientation":"v","showlegend":false,"x":["2024-01-29","2023-07-31","2023-05-01","2023-01-30","2022-08-01","2022-05-02","2022-01-31","2021-08-02","2021-05-03","2021-02-01","2020-07-27","2020-04-27","2020-01-27","2019-07-29","2019-04-29","2019-01-28"],"xaxis":"x2","y":[3497000000.0,2983000000.0,2662000000.0,2508000000.0,2576000000.0,2416000000.0,3563000000.0,1960000000.0,1771000000.0,1673000000.0,1562000000.0,1624000000.0,1028000000.0,989000000.0,970000000.0,938000000.0],"yaxis":"y2","type":"scatter"},{"hovertemplate":"symbol=TSLA\u003cbr\u003eFinancial Metric=gross_profit\u003cbr\u003estart_date=%{x}\u003cbr\u003eDollars=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TSLA","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"TSLA","orientation":"v","showlegend":true,"x":["2024-01-01","2023-07-0 ...

# %% [markdown]
# ### Save graph to image if you want

# %%
# !pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in /usr/local/lib/python3.10/dist-packages (0.2.1)

# %%
fig.write_image("fig1.png")
